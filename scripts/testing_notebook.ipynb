# %%
import eos
import numpy as np

# %%
eos.Observables(prefix='B_s->phill', name='A_')
# Out:
#         <script>
#             function toggle_group(group_title, id) {
#                 var table = group_title.parentNode.parentNode.parentNode.parentNode
#                 var query = 'tbody[id="' + id + '"]'
#                 var group = table.querySelector(query)
#                 if (group.style.visibility == "collapse") {
#                     group.style.visibility = "visible"
#                 } else {
#                     group.style.visibility = "collapse"
#                 }
#             }
#             function toggle_av(opt_anchor, id) {
#                 var query_dots   = 'span.dots[id="' + id + '"]'
#                 var query_values = 'span.values[id="' + id + '"]'
#                 var dots   = opt_anchor.querySelector(query_dots)
#                 var values = opt_anchor.querySelector(query_values)
#                 if (dots.style.display == "none") {
#                     dots.style.display   = "inline"
#                     values.style.display = "none"
# ...

# %%
eos.Observables()['B_s->phill::KP_5p@LHCb']
# Out:
# <table>
# <tr><th>QualifedName</th><td><tt style="color:grey">B_s->phill::KP_5p@LHCb</tt></td></tr><tr><th>Description</th><td>$$KP_{5p}(\bar{B}_s\to \phi\ell^+\ell^-)$$</td></tr><tr><th rowspan=2>Kinematic Variables</th><td>q2_max</td></tr><tr><td>q2_min</td></tr></table>

# %%
parameters = eos.Parameters.Defaults()
obs = eos.Observable.make('B_s->phill::M_8@LHCb', parameters, eos.Kinematics(q2_min=4.0, q2_max=6.0), eos.Options(tag='GvDV2020'))
display(obs)
parameters = eos.Parameters.Defaults()
obs = eos.Observable.make('B_s->phill::M_8(q2)@LHCb', parameters, eos.Kinematics(q2=1.1), eos.Options(tag='GvDV2020'))
display(obs)
parameters = eos.Parameters.Defaults()
# Out:
#         <table>
#             <tr>
#                 <th>B_s->phill::M_8@LHCb</th>
#                 <td colspan="2">(eos.Observable)</td>
#             </tr>
#             <tr>
#                 <th rowspan="2">kinematics</th>
#                 <th>q2_min</th><td>4.0</td>
#             </tr>
#             <tr><th>q2_max</th><td>6.0</td></tr>
#             <tr>
#                 <th rowspan="1">options</th>
#                 <th>tag</th><td>GvDV2020</td>
#             </tr>
#
#             <tr>
#                 <th>current value</th>
#                 <td colspan="2"><tt>-0.01915</tt></td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <th>B_s->phill::M_8(q2)@LHCb</th>
#                 <td colspan="2">(eos.Observable)</td>
#             </tr>
#             <tr>
#                 <th rowspan="1">kinematics</th>
#                 <th>q2</th><td>1.1</td>
#             </tr>
#
#             <tr>
# ...

# %%
parameters = eos.Parameters.Defaults()
obs = eos.Observable.make('B_s->phill::Q_8@LHCb', parameters, eos.Kinematics(q2_min=4.0, q2_max=6.0), eos.Options(tag='GvDV2020'))
display(obs)
parameters = eos.Parameters.Defaults()
obs = eos.Observable.make('B_s->phill::Q_8(q2)@LHCb', parameters, eos.Kinematics(q2=1.1), eos.Options(tag='GvDV2020'))
display(obs)
parameters = eos.Parameters.Defaults()
# Out:
#         <table>
#             <tr>
#                 <th>B_s->phill::Q_8@LHCb</th>
#                 <td colspan="2">(eos.Observable)</td>
#             </tr>
#             <tr>
#                 <th rowspan="2">kinematics</th>
#                 <th>q2_min</th><td>4.0</td>
#             </tr>
#             <tr><th>q2_max</th><td>6.0</td></tr>
#             <tr>
#                 <th rowspan="1">options</th>
#                 <th>tag</th><td>GvDV2020</td>
#             </tr>
#
#             <tr>
#                 <th>current value</th>
#                 <td colspan="2"><tt>0.3762</tt></td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <th>B_s->phill::Q_8(q2)@LHCb</th>
#                 <td colspan="2">(eos.Observable)</td>
#             </tr>
#             <tr>
#                 <th rowspan="1">kinematics</th>
#                 <th>q2</th><td>1.1</td>
#             </tr>
#
#             <tr>
# ...

# %%
import matplotlib as mpl
cmap = mpl.cm.get_cmap('tab20')
norm = mpl.colors.Normalize(vmin=0, vmax=12)
colors = [cmap(norm(i)) for i in range(12)]

plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.1, 13.5] },
        'y': { 'label': r'$\mathcal{Z}_{i}$',                          'range': [-0.5, 0.5] },
        'legend': { 'location': 'center right' }
    },
    'contents': [
        {
            'label': r'$\mathcal{Z}_{' + obs + '}$',
            'type': 'observable',
            'observable': f'B_s->phill::Z_{obs}(q2)@LHCb',
            'variable': 'q2',
            'color': colors[j],
            'range': [0.5, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020'}
        } for j, obs in enumerate(['1s', '1c', '2s', '2c', '3', '4', '5', '6s', '6c', '7', '8', '9'])
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
# /var/folders/zs/ctw2h2zj4h3b_nvd1_kp99140000gn/T/ipykernel_47955/701398462.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = mpl.cm.get_cmap('tab20')
#    plotting EOS observable "B_s->phill::Z_1s(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_1c(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_2s(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_2c(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_3(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_4(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_5(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_6s(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_6c(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_7(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Z_8(q2)@LHCb"
# ...

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.1, 13.5] },
        'y': { 'label': r'$\mathcal{H}_{i}$',                          'range': [-1.0, 1.0] },
        'legend': { 'location': 'center right' }
    },
    'contents': [
        {
            'label': r'$\mathcal{H}_{' + obs + '}$',
            'type': 'observable',
            'observable': f'B_s->phill::H_{obs}(q2)@LHCb',
            'variable': 'q2',
            'color': colors[j],
            'range': [0.5, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020'}
        } for j, obs in enumerate(['1s', '1c', '2s', '2c', '3', '4', '5', '6s', '6c', '7', '8', '9'])
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
#    plotting EOS observable "B_s->phill::H_1s(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_1c(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_2s(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_2c(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_3(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_4(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_5(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_6s(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_6c(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_7(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_8(q2)@LHCb"
#    plotting EOS observable "B_s->phill::H_9(q2)@LHCb"

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.1, 13.5] },
        'y': { 'label': r'$h_{i}$',                       },
        'legend': { 'location': 'center right' }
    },
    'contents': [
        {
            'label': r'$h_{' + obs + '}$',
            'type': 'observable',
            'observable': f'B_s->phill::H_{obs}(q2)',
            'variable': 'q2',
            'color': colors[j],
            'range': [0.5, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020'}
        } for j, obs in enumerate(['1s', '1c', '2s', '2c', '3', '4', '5', '6s', '6c', '7', '8', '9'])
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
#    plotting EOS observable "B_s->phill::H_1s(q2)"
#    plotting EOS observable "B_s->phill::H_1c(q2)"
#    plotting EOS observable "B_s->phill::H_2s(q2)"
#    plotting EOS observable "B_s->phill::H_2c(q2)"
#    plotting EOS observable "B_s->phill::H_3(q2)"
#    plotting EOS observable "B_s->phill::H_4(q2)"
#    plotting EOS observable "B_s->phill::H_5(q2)"
#    plotting EOS observable "B_s->phill::H_6s(q2)"
#    plotting EOS observable "B_s->phill::H_6c(q2)"
#    plotting EOS observable "B_s->phill::H_7(q2)"
#    plotting EOS observable "B_s->phill::H_8(q2)"
#    plotting EOS observable "B_s->phill::H_9(q2)"

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.1, 13.5] },
        'y': { 'label': r'$s_{i}$',                           },
        'legend': { 'location': 'center right' }, 
        'cmap': 'tab20',
    },
    'contents': [
        {
            'label': r'$s_{' + obs + '}$',
            'type': 'observable',
            'observable': f'B_s->phill::Z_{obs}(q2)',
            'variable': 'q2',
            'color': colors[j],
            'range': [0.5, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020'}
        } for j, obs in enumerate(['1s', '1c', '2s', '2c', '3', '4', '5', '6s', '6c', '7', '8', '9'])
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
#    plotting EOS observable "B_s->phill::Z_1s(q2)"
#    plotting EOS observable "B_s->phill::Z_1c(q2)"
#    plotting EOS observable "B_s->phill::Z_2s(q2)"
#    plotting EOS observable "B_s->phill::Z_2c(q2)"
#    plotting EOS observable "B_s->phill::Z_3(q2)"
#    plotting EOS observable "B_s->phill::Z_4(q2)"
#    plotting EOS observable "B_s->phill::Z_5(q2)"
#    plotting EOS observable "B_s->phill::Z_6s(q2)"
#    plotting EOS observable "B_s->phill::Z_6c(q2)"
#    plotting EOS observable "B_s->phill::Z_7(q2)"
#    plotting EOS observable "B_s->phill::Z_8(q2)"
#    plotting EOS observable "B_s->phill::Z_9(q2)"

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.1, 10.0] },
        'y': { 'label': r'$Q_{i}$',                           },
        'legend': { 'location': 'center right' }
    },
    'contents': [
        {
            'label': r'$Q_{8}^-$',
            'type': 'observable',
            'observable': 'B_s->phill::Q_8^-(q2)@LHCb',
            'variable': 'q2',
            'range': [0.02, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020', 'q': 's'}
        },
        {
            'label': r'$Q_{9}$',
            'type': 'observable',
            'observable': 'B_s->phill::Q_9(q2)@LHCb',
            'variable': 'q2',
            'range': [0.02, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020', 'q': 's'}
        },
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
#    plotting EOS observable "B_s->phill::Q_8^-(q2)@LHCb"
#    plotting EOS observable "B_s->phill::Q_9(q2)@LHCb"

# %%
EOS_BASE_DIRECTORY = './predictions-data/'
eos.tasks.sample_prior('./predictions.yaml', 'FF-LQCD-SSE', base_directory=EOS_BASE_DIRECTORY, N=2000, seed=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 EOS_BASE_DIRECTORY = './predictions-data/'
# ----> 2 eos.tasks.sample_prior('./predictions.yaml', 'FF-LQCD-SSE', base_directory=EOS_BASE_DIRECTORY, N=2000, seed=42)
#
# File ~/eos_test_rmafter/eos/.venv/lib/python3.13/site-packages/eos/tasks.py:95, in task.<locals>._task.<locals>.task_wrapper(*args, **kwargs)
#      93 ioutput = contextlib.suppress() # can be replaced with contextlib.nullcontext once Python >=3.7 is ensured
#      94 if __ipython__:
# ---> 95     import ipywidgets as _ipywidgets
#      96     ioutput = _ipywidgets.Output(layout={'height': '200px', 'overflow': 'auto'})
#      97     iaccordion = _ipywidgets.Accordion(children=[ioutput])
#
# ModuleNotFoundError: No module named 'ipywidgets'

# %%
eos.tasks.predict_observables('predictions.yaml', 'FF-LQCD-SSE', 'B-to-D-mu-nu',  base_directory=EOS_BASE_DIRECTORY)
eos.tasks.predict_observables('predictions.yaml', 'FF-LQCD-SSE', 'B-to-D-tau-nu',  base_directory=EOS_BASE_DIRECTORY)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('FF-LQCD-SSE/pred-B-to-D…
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('FF-LQCD-SSE/pred-B-to-D…

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2$', 'range': [0.0, 11.60] },
        'y': { 'label': r'$d\mathcal{B}/dq^2$',                    'range': [0.0,  5e-3] },
        'legend': { 'location': 'upper center' }
    },
    'contents': [
        {
          'label': r'$\ell=\mu$', 'type': 'uncertainty', 'range': [0.02, 11.60],
          'data-file': f'{EOS_BASE_DIRECTORY}/FF-LQCD-SSE/pred-B-to-D-mu-nu'
        },
        {
          'label': r'$\ell=\tau$','type': 'uncertainty', 'range': [3.17, 11.60],
          'data-file': f'{EOS_BASE_DIRECTORY}/FF-LQCD-SSE/pred-B-to-D-tau-nu'
        },
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
#    plotting uncertainty propagation from "./predictions-data//FF-LQCD-SSE/pred-B-to-D-mu-nu"
#    plotting uncertainty propagation from "./predictions-data//FF-LQCD-SSE/pred-B-to-D-tau-nu"

# %%
eos.Constraints(name='FormFactors')
# Out:
#         <script>
#             function toggle_obs(obs_anchor, id) {
#                 var query_dots   = 'span.dots[id="' + id + '"]'
#                 var query_values = 'span.values[id="' + id + '"]'
#                 var dots   = obs_anchor.querySelector(query_dots)
#                 var values = obs_anchor.querySelector(query_values)
#                 if (dots.style.display == "none") {
#                     dots.style.display   = "inline"
#                     values.style.display = "none"
#                 } else {
#                     dots.style.display   = "none"
#                     values.style.display = "inline"
#                 }
#             }
#         </script>
#         <table>
#             <colgroup>
#                 <col width="50%" id="qn"     style="min-width: 200px">
#                 <col width="25%" id="type"   style="min-width: 200px">
#                 <col width="15%" id="type"   style="min-width: 100px">
# ...

# %%
EOS_BASE_DIRECTORY = './predictions-data/'
eos.tasks.sample_prior('./phi_mumu_angular.yaml', 'FF-POST', base_directory=EOS_BASE_DIRECTORY, N=2000, seed=42)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('FF-POST/samples',))

# %%
eos.tasks.predict_observables('./phi_mumu_angular.yaml', 'FF-POST', 'Bs_to_phi_mumu', base_directory=EOS_BASE_DIRECTORY)
# Out:
# Accordion(children=(Output(layout=Layout(height='200px', overflow='auto')),), titles=('FF-POST/pred-Bs_to_phi_…

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.0, 11.60] },
        'y': { 'label': r'$\mathcal{Z}_{1c}$',                          },
        'legend': { 'location': 'best' }
    },
    'contents': [
        {
          'label': r'', 'type': 'uncertainty', 'range': [0.1, 10.0],
          'data-file': f'{EOS_BASE_DIRECTORY}/FF-POST/pred-Bs_to_phi_mumu',
          'observable': 'B_s->phill::Z_1c(q2)@LHCb;l=mu'
        },
        {
          'label': r'', 'type': 'uncertainty', 'range': [0.1, 10.0],
          'data-file': f'{EOS_BASE_DIRECTORY}/FF-POST/pred-Bs_to_phi_mumu',
          'observable': 'B_s->phill::H_3(q2)@LHCb;l=mu'
        },
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
#    plotting uncertainty propagation from "./predictions-data//FF-POST/pred-Bs_to_phi_mumu"
#    plotting uncertainty propagation from "./predictions-data//FF-POST/pred-Bs_to_phi_mumu"

# %%
import numpy as np
file = np.load('predictions-data/FF-POST/pred-Bs_to_phi_mumu/samples.npy')
file
# Out:
# array([[-0.20469095, -0.26384784, -0.28778601, ..., -0.04321566,
#         -0.04180758, -0.04036282],
#        [-0.20360025, -0.26233048, -0.28638632, ..., -0.03698508,
#         -0.03677573, -0.03660595],
#        [-0.21374552, -0.28113571, -0.31273173, ..., -0.0462825 ,
#         -0.04604072, -0.04575833],
#        ...,
#        [-0.19721009, -0.25061363, -0.27009479, ..., -0.03703491,
#         -0.03620911, -0.03540503],
#        [-0.15835742, -0.18430366, -0.18357091, ..., -0.02862539,
#         -0.02688597, -0.0253478 ],
#        [-0.2143721 , -0.28273412, -0.31563397, ..., -0.03478623,
#         -0.03543084, -0.03602499]], shape=(2000, 60))

# %%
parameters = eos.Parameters.Defaults()
obs = [eos.Observable.make('B_s->phill::Q_9(q2)@LHCb', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
np.savez('predictions-data/q9.npz', q2=np.linspace(0.1, 10.0, 100), Q9=obs)

# %%
parameters = eos.Parameters.Defaults()
q8mi = [eos.Observable.make('B_s->phill::Q_8^-(q2)@LHCb', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
np.savez('predictions-data/q8mi.npz', q2=np.linspace(0.1, 10.0, 100), Q8mi=q8mi)

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.1, 13.5] },
        'y': { 'label': r'$A_X$',                           },
        'legend': { 'location': 'center right' }, 
    },
    'contents': [
        {
            'label': amplitude,
            'type': 'observable',
            'observable': f'B_s->phill::{amplitude}_real',
            'variable': 'q2',
            'range': [0.5, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020'}
        } for amplitude in ['A_0_left', 'A_0_right', 'A_para_left', 'A_para_right', 'A_perp_left', 'A_perp_right', 'A_time', 'A_scal']
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
parameters = eos.Parameters.Defaults()
A_0_left_real = [eos.Observable.make('B_s->phill::A_0_left_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_0_right_real = [eos.Observable.make('B_s->phill::A_0_right_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_0_left_imag = [eos.Observable.make('B_s->phill::A_0_left_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_0_right_imag = [eos.Observable.make('B_s->phill::A_0_right_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]

A_para_left_real = [eos.Observable.make('B_s->phill::A_para_left_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_para_right_real = [eos.Observable.make('B_s->phill::A_para_right_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_para_left_imag = [eos.Observable.make('B_s->phill::A_para_left_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_para_right_imag = [eos.Observable.make('B_s->phill::A_para_right_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]

A_perp_left_real = [eos.Observable.make('B_s->phill::A_perp_left_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_perp_right_real = [eos.Observable.make('B_s->phill::A_perp_right_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_perp_left_imag = [eos.Observable.make('B_s->phill::A_perp_left_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_perp_right_imag = [eos.Observable.make('B_s->phill::A_perp_right_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]

A_time_real = [eos.Observable.make('B_s->phill::A_time_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_time_imag = [eos.Observable.make('B_s->phill::A_time_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_scal_real = [eos.Observable.make('B_s->phill::A_scal_real', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]
A_scal_imag = [eos.Observable.make('B_s->phill::A_scal_imag', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in np.linspace(0.1, 10.0, 100)]

if True:
    np.savez('predictions-data/amplitudes.npz', q2=np.linspace(0.1, 10.0, 100), A_time_real=A_time_real, A_time_imag=A_time_imag, A_scal_real=A_scal_real, A_scal_imag=A_scal_imag,
             A_0_left_real=A_0_left_real, A_0_right_real=A_0_right_real, A_0_left_imag=A_0_left_imag, A_0_right_imag=A_0_right_imag,
             A_para_left_real=A_para_left_real, A_para_right_real=A_para_right_real, A_para_left_imag=A_para_left_imag, A_para_right_imag=A_para_right_imag,
            A_perp_left_real=A_perp_left_real, A_perp_right_real=A_perp_right_real, A_perp_left_imag=A_perp_left_imag, A_perp_right_imag=A_perp_right_imag,)
# Out:
#    plotting EOS observable "B_s->phill::A_0_left_real"
#    plotting EOS observable "B_s->phill::A_0_right_real"
#    plotting EOS observable "B_s->phill::A_para_left_real"
#    plotting EOS observable "B_s->phill::A_para_right_real"
#    plotting EOS observable "B_s->phill::A_perp_left_real"
#    plotting EOS observable "B_s->phill::A_perp_right_real"
#    plotting EOS observable "B_s->phill::A_time_real"
#    plotting EOS observable "B_s->phill::A_scal_real"

# %%
plot_args = {
    'plot': {
        'x': { 'label': r'$q^2$', 'unit': r'$\textnormal{GeV}^2/c^4$', 'range': [0.1, 13.5] },
        'y': { 'label': r'$A_X$',                           },
        'legend': { 'location': 'center right' }, 
    },
    'contents': [
        {
            'label': amplitude,
            'type': 'observable',
            'observable': f'B_s->phill::{amplitude}_imag',
            'variable': 'q2',
            'range': [0.5, 10.0],
            'tag': 'GvDV2020',
            'options': {'tag': 'GvDV2020'}
        } for amplitude in ['A_0_left', 'A_0_right', 'A_para_left', 'A_para_right', 'A_perp_left', 'A_perp_right', 'A_time', 'A_scal']
    ]
}
_ = eos.plot.Plotter(plot_args).plot()
# Out:
#    plotting EOS observable "B_s->phill::A_0_left_imag"
#    plotting EOS observable "B_s->phill::A_0_right_imag"
#    plotting EOS observable "B_s->phill::A_para_left_imag"
#    plotting EOS observable "B_s->phill::A_para_right_imag"
#    plotting EOS observable "B_s->phill::A_perp_left_imag"
#    plotting EOS observable "B_s->phill::A_perp_right_imag"
#    plotting EOS observable "B_s->phill::A_time_imag"
#    plotting EOS observable "B_s->phill::A_scal_imag"

# %%
eos.Parameters()['B_s::q_over_p_phase']
from numpy import cos, sin
complex(cos(-0.05), sin(-0.05))
# Out:
# (0.9987502603949663-0.04997916927067833j)

# %%
eos.Parameters()['B_s::q_over_p_phase']
# Out:
#     <table>
#         <tr>
#             <th>$$\phi_{B_s}$$</th>
#             <td>(eos.Parameter)</td>
#         </tr>
#         <tr>
#             <th>current value</th>
#             <td><tt>-0.05</tt></td>
#         </tr>
#         <tr>
#             <th>default value</th>
#             <td><tt>-0.05</tt></td>
#         </tr>
#     </table>

# %%
import eos 
import numpy as np
qsq_array = np.linspace(0.1, 10.0, 30)
parameters = eos.Parameters.Defaults()
parameters.set("B_s::q_over_p_phase", -0.036)
obses = [f'{_obs}_{_ind}' for _obs in ['Z', 'H', 'S', 'A', 'W', 'K'] for _ind in ['1s', '1c', '2s', '2c', '3', '4', '5', '6s', '6c', '7', '8', '9']]
result = {obs: [eos.Observable.make(f'B_s->phill::{obs}(q2)@LHCb', parameters, eos.Kinematics(q2=q2), eos.Options(q='s', tag='GvDV2020')).evaluate() for q2 in qsq_array] for obs in obses}
print(result)
# Out:
# {'Z_1s': [-0.0010708907513636379, -0.0009362318076971094, -0.0007345812769933541, -0.0005258415319645482, -0.0003206776892173284, -0.00012252528002737765, 6.771870059158738e-05, 0.00025020580479396984, 0.00042552622072031374, 0.0005944394018889608, 0.0007577500042127447, 0.0009162509996942279, 0.001070700196947561, 0.0012218126414652382, 0.001370261210876861, 0.0015166807427668678, 0.001661674194223894, 0.0018058191680171227, 0.0019496747350678297, 0.0020937879723350343, 0.0022387004685108427, 0.002384954524740506, 0.0025330993631443037, 0.0026836972220555125, 0.0028373296388102087, 0.002994603885720469, 0.0031561597961936388, 0.00332267702741301, 0.003494883035678382, 0.003673561863463565], 'Z_1c': [0.007080692963467443, 0.020137264409122984, 0.026927401148220804, 0.030536937511183318, 0.03236340176310615, 0.03313835163280956, 0.03327356102220325, 0.03301281674776489, 0.03250606120802168, 0.03184819800999989, 0.031100611627633185, 0.030303612893653905, 0.029483951978275993, 0.028659
# ...

# %%
np.savez('eos_predictions_data.npz', qsq_array=qsq_array, **result)

# %%
eos.Parameters(prefix='B_s->phi')
# Out:
#         <table>
#             <colgroup>
#                 <col width="25%" id="qn"      style="min-width: 200px">
#                 <col width="20%" id="symbol"  style="min-width: 200px">
#                 <col width="5%"  id="unit"    style="min-width:  50px">
#                 <col width="10%" id="value"   style="min-width: 100px">
#             </colgroup>
#             <thead>
#                 <tr>
#                     <th>qualified name</th>
#                     <th>symbol</th>
#                     <th>unit</th>
#                     <th>value</th>
#                 </tr>
#             </thead>
#
#               <tr><th style="text-align:left" colspan=4><big>Hadron Property Parameters</big></th></tr>
#                     <tr><th style="text-align:left" colspan=4>Parameters in Light-Cone Distribution Amplitudes</th></tr>
#                     <tr><td style="text-align:left" colspan=4></td></tr>
#                         <tbody>
#                             <tr>
# ...

# %%
eos.Parameters()['life_time::B_s']
# Out:
#     <table>
#         <tr>
#             <th>$$\tau_{B_s}$$</th>
#             <td>(eos.Parameter)</td>
#         </tr>
#         <tr>
#             <th>current value</th>
#             <td><tt>1.516e-12</tt></td>
#         </tr>
#         <tr>
#             <th>default value</th>
#             <td><tt>1.516e-12</tt></td>
#         </tr>
#     </table>

# %%
eos.Observable.make(f'B_s->phill::S_1c@LHCb', parameters, eos.Kinematics(q2_min=1.1, q2_max=6.0), eos.Options(q='s', tag='GvDV2020'))
# Out:
#         <table>
#             <tr>
#                 <th>B_s->phill::S_1c@LHCb</th>
#                 <td colspan="2">(eos.Observable)</td>
#             </tr>
#             <tr>
#                 <th rowspan="2">kinematics</th>
#                 <th>q2_min</th><td>1.1</td>
#             </tr>
#             <tr><th>q2_max</th><td>6.0</td></tr>
#             <tr>
#                 <th rowspan="2">options</th>
#                 <th>q</th><td>s</td>
#             </tr>
#             <tr><th>tag</th><td>GvDV2020</td></tr>
#             <tr>
#                 <th>current value</th>
#                 <td colspan="2"><tt>0.7047</tt></td>
#             </tr>
#         </table>

# %%
eos.Observable.make(f'B_s->phill::S_1c(q2)@LHCb', parameters, eos.Kinematics(q2=1.0), eos.Options(q='s', tag='GvDV2020', l='mu', formfactors='BSZ2015'))
# Out:
#         <table>
#             <tr>
#                 <th>B_s->phill::S_1c(q2)@LHCb</th>
#                 <td colspan="2">(eos.Observable)</td>
#             </tr>
#             <tr>
#                 <th rowspan="1">kinematics</th>
#                 <th>q2</th><td>1.0</td>
#             </tr>
#
#             <tr>
#                 <th rowspan="4">options</th>
#                 <th>formfactors</th><td>BSZ2015</td>
#             </tr>
#             <tr><th>l</th><td>mu</td></tr>
# <tr><th>q</th><td>s</td></tr>
# <tr><th>tag</th><td>GvDV2020</td></tr>
#             <tr>
#                 <th>current value</th>
#                 <td colspan="2"><tt>0.6829</tt></td>
#             </tr>
#         </table>
